# %% [markdown]
# # tblastn Truth Breakdown: Usable Clean
#
# Records must have canonical truth names, but duplicated canonical names are allowed.
#
# Generated artifacts are written to `outputs/`.

# %% [markdown]
# ## What To Look At
#
# Use the summary first, then inspect failure modes and review cases. `coord_pct` is the main score: same canonical name and IoU >= 0.90 against the annotated truth feature.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'app').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

import matplotlib.pyplot as plt
import pandas as pd

from app.validation._shared.validation_utils import *

TIER = 'usable_clean'
BASE_DIR = Path.cwd()
if not (BASE_DIR / 'inputs').exists() and (BASE_DIR / 'tiers' / TIER / 'inputs').exists():
    BASE_DIR = BASE_DIR / 'tiers' / TIER

INPUT_DIR = BASE_DIR / 'inputs'
OUTPUT_DIR = BASE_DIR / 'outputs'
OUTPUT_DIR.mkdir(exist_ok=True)

FAILURE_COLORS = {
    'Correct': '#2f7d4f',
    'Boundary offset': '#75b66b',
    'Wrong coords': '#d6a13d',
    'Alias/name gap': '#8f6bb1',
    'Possible overlap': '#e28e50',
    'Not lifted': '#c44e52',
    'Not in truth': '#7b8794',
}

# %% [markdown]
# ## Tier Inputs
#
# The manifest records which source records were kept or rejected for this tier. The GenBank files in `inputs/` are the actual records used below.

# %%
manifest = pd.read_csv(INPUT_DIR / 'manifest.tsv', sep='	')
tier_input_summary = pd.read_csv(INPUT_DIR / 'summary.tsv', sep='	')
tier_input_summary
# Out:
#   virus                      reason  records  kept
# 0   FMD                  kept_clean       98    98
# 1   FMD           no_truth_features        2     0
# 2  PRRS                  kept_clean       96    96
# 3  PRRS  noncanonical_truth:ignored        4     0

# %% [markdown]
# ## Run tblastn Against Tier Truth
#
# This uses the same `run_tblastn_against_truth` helper as the original breakdown notebook, but swaps the query files for this tier's cleaned inputs.

# %%
DATASETS = [
    ('PRRS', DATA / 'PRRS_ref_test.gb', INPUT_DIR / 'PRRS_records.gb'),
    ('FMD', DATA / 'FMD_ref_test.gb', INPUT_DIR / 'FMD_records.gb'),
]

frames = []
summaries = []
for virus, ref_path, query_path in DATASETS:
    records = load_genbank_records(query_path)
    if not records:
        continue
    df, summary = run_tblastn_against_truth(virus, ref_path, query_path, OUTPUT_DIR / virus.lower())
    if not df.empty:
        frames.append(df)
    if not summary.empty:
        summaries.append(summary)

tblastn_df = pd.concat(frames, ignore_index=True) if frames else pd.DataFrame()
tblastn_summary = pd.concat(summaries, ignore_index=True) if summaries else pd.DataFrame()

tblastn_df.to_csv(OUTPUT_DIR / 'tblastn_vs_truth.tsv', sep='	', index=False)
tblastn_summary.to_csv(OUTPUT_DIR / 'tblastn_summary.tsv', sep='	', index=False)
tblastn_summary
# Out:
#   virus   method  total  exact  coord_correct  mean_iou  exact_pct  coord_pct
# 0  PRRS  tblastn    864    598            690    0.8268      69.21      79.86
# 1   FMD  tblastn   1176   1110           1153    0.9927      94.39      98.04

# %% [markdown]
# ## Failure Modes
#
# This shows whether remaining misses are boundary shifts, wrong coordinates, name gaps, or partial overlaps.

# %%
if tblastn_df.empty:
    failure_modes = pd.DataFrame()
else:
    failure_modes = (
        tblastn_df.groupby(['virus', 'failure_mode'])
        .size()
        .reset_index(name='count')
        .sort_values(['virus', 'count'], ascending=[True, False])
    )
    failure_modes['total'] = failure_modes.groupby('virus')['count'].transform('sum')
    failure_modes['pct'] = (failure_modes['count'] / failure_modes['total'] * 100).round(2)

failure_modes.to_csv(OUTPUT_DIR / 'tblastn_failure_modes.tsv', sep='	', index=False)
failure_modes
# Out:
#    virus      failure_mode  count  total    pct
# 1    FMD           Correct   1110   1176  94.39
# 0    FMD   Boundary offset     43   1176   3.66
# 5    FMD      Wrong coords     19   1176   1.62
# 2    FMD      Not in truth      2   1176   0.17
# 3    FMD        Not lifted      1   1176   0.09
# 4    FMD  Possible overlap      1   1176   0.09
# 8   PRRS           Correct    598    864  69.21
# 10  PRRS  Possible overlap    120    864  13.89
# 7   PRRS   Boundary offset     92    864  10.65
# 11  PRRS      Wrong coords     30    864   3.47
# 6   PRRS    Alias/name gap     23    864   2.66
# 9   PRRS      Not in truth      1    864   0.12

# %%
if not failure_modes.empty:
    failure_order = ['Correct', 'Boundary offset', 'Wrong coords', 'Alias/name gap', 'Possible overlap', 'Not lifted', 'Not in truth']
    plot_df = failure_modes.pivot_table(index='virus', columns='failure_mode', values='pct', fill_value=0)
    plot_df = plot_df.reindex(columns=failure_order, fill_value=0)

    fig, ax = plt.subplots(figsize=(9, 4.5))
    left = pd.Series(0, index=plot_df.index, dtype=float)
    for failure in failure_order:
        values = plot_df[failure]
        ax.barh(plot_df.index, values, left=left.values, color=FAILURE_COLORS[failure], label=failure)
        left += values

    ax.set_xlim(0, 100)
    ax.set_xlabel('Percent of predictions')
    ax.set_ylabel('')
    ax.set_title(f'tblastn failure mode mix: {TIER}')
    ax.legend(ncol=3, loc='lower center', bbox_to_anchor=(0.5, -0.34), frameon=False)
    fig.tight_layout()
    fig.savefig(OUTPUT_DIR / 'tblastn_failure_modes.png', dpi=180, bbox_inches='tight')
    display(plot_df)
# Out:
# failure_mode  Correct  Boundary offset  Wrong coords  Alias/name gap  \
# virus
# FMD             94.39             3.66          1.62            0.00
# PRRS            69.21            10.65          3.47            2.66
#
# failure_mode  Possible overlap  Not lifted  Not in truth
# virus
# FMD                       0.09        0.09          0.17
# PRRS                     13.89        0.00          0.12

# %% [markdown]
# ## Feature-Level Accuracy
#
# Low rows here are the best candidates for real lifting improvements, after the tier has reduced annotation noise.

# %%
if tblastn_df.empty:
    by_gene = pd.DataFrame()
else:
    by_gene = summarize_comparison(tblastn_df, ['virus', 'pred_name'])
by_gene.to_csv(OUTPUT_DIR / 'tblastn_per_gene.tsv', sep='	', index=False)
by_gene.sort_values(['virus', 'coord_pct']).head(30)
# Out:
#    virus pred_name  total  exact  coord_correct  mean_iou  exact_pct  \
# 0    FMD        2A     98     73             82    0.9677      74.49
# 4    FMD        3B     98     95             96    0.9863      96.94
# 3    FMD        3A     98     97             97    0.9974      98.98
# 8    FMD       VP1     98     80             97    0.9882      81.63
# 9    FMD       VP2     98     97             97    0.9968      98.98
# 10   FMD       VP3     98     97             97    0.9898      98.98
# 11   FMD       VP4     98     97             97    0.9898      98.98
# 1    FMD        2B     98     98             98    1.0000     100.00
# 2    FMD        2C     98     98             98    1.0000     100.00
# 5    FMD     3Cpro     98     96             98    0.9996      97.96
# 6    FMD     3Dpol     98     98             98    1.0000     100.00
# 7    FMD      Lpro     98     84             98    0.9971      85.71
# 15  PRRS     ORF2b     96      0              0    0.0000       0.00
# 12  PRRS     ORF1a     96     61             62    0.6458      63.54
# 20  PRRS      ORF7     96     67             67    0.9556      69.79
# 13  PRRS     ORF1b     96      0             83    0.8629       0.00
# 18  PRRS      ORF5     96     91             95    0.9892      94.79
# 19  PRRS      ORF6     96     92             95    0.9888      95.83
# 14  PRRS     ORF2a     96     96             96    1.0000     100.00
# 16  PRRS      ORF3     96     96             96    1.0000     100.00
# 17  PRRS      ORF4     96     95             96    0.9992      98.96
#
#     coord_pct
# 0       83.67
# 4       97.96
# 3       98.98
# 8       98.98
# 9       98.98
# 10      98.98
# 11      98.98
# 1      100.00
# 2      100.00
# 5      100.00
# 6      100.00
# 7      100.00
# 15       0.00
# 12      64.58
# 20      69.79
# 13      86.46
# 18      98.96
# 19      98.96
# 14     100.00
# 16     100.00
# 17     100.00

# %% [markdown]
# ## Review Cases
#
# These are the non-correct predictions to inspect manually. For name-gap questions, compare `pred_name`, `truth_name`, and `best_overlap_name`.

# %%
if tblastn_df.empty:
    review_cases = pd.DataFrame()
else:
    review_cases = tblastn_df[tblastn_df['failure_mode'] != 'Correct'].copy()
    review_cases = review_cases.sort_values(['virus', 'failure_mode', 'record_id', 'pred_name'])
review_cases.to_csv(OUTPUT_DIR / 'tblastn_review_cases.tsv', sep='	', index=False)
review_cases.head(50)
# Out:
#      virus   record_id   method pred_name source_name  pred_start  pred_end  \
# 868    FMD  AY687333.1  tblastn       VP1        None      3251.0    3880.0
# 880    FMD  AY687334.1  tblastn       VP1        None      3250.0    3876.0
# 1253   FMD  DQ533483.2  tblastn        2A        None      3893.0    3943.0
# 905    FMD  DQ989304.1  tblastn        2A        None      3934.0    3984.0
# 1013   FMD  DQ989313.1  tblastn        2A        None      3980.0    4030.0
# 1056   FMD  DQ989317.1  tblastn      Lpro        None      1194.0    1784.0
# 1068   FMD  DQ989318.1  tblastn      Lpro        None      1190.0    1780.0
# 1241   FMD  GU931682.1  tblastn        2A        None      3892.0    3942.0
# 1260   FMD  KJ754939.1  tblastn      Lpro        None      1113.0    1703.0
# 1277   FMD  LC036265.1  tblastn        2A        None      3906.0    3956.0
# 1276   FMD  LC036265.1  tblastn       VP1        None      3270.0    3902.0
# 1300   FMD  MF372126.1  tblastn       VP1        None      3355.0    3978.0
# 1308   FMD  MG372727.1  tblastn      Lpro        None      1051.0    1632.0
# 1312   FMD  MG372727.1  tblastn       VP1        None      3220.0    3867.0
# 1324   FMD  MG372728.1  tblastn       VP1        None      3227.0    3859.0
# 1336   FMD  MG372729.1  tblastn       VP1        None      3221.0    3841.0
# 1348   FMD  MG372730.1  tblastn       VP1        None      3210.0    3842.0
# 1360   FMD  MG372731.1  tblastn       VP1        None      3284.0    3919.0
# 1372   FMD  MG372732.1  tblastn       VP1        None      2795.0    3415.0
# 1612   FMD  MK088170.1  tblastn       VP1        None      3271.0    3903.0
# 1380   FMD  MK088171.1  tblastn      Lpro        None      1114.0    1704.0
# 1416   FMD  MN095356.1  tblastn      Lpro        None      1102.0    1692.0
# 1428   FMD  MN095357.1  tblastn      Lpro        None      1109.0    1699.0
# 1440   FMD  MN095358.1  tblastn      Lpro        None      1091.0    1681.0
# 1452   FMD  MN095359.1  tblastn      Lpro        None      1093.0    1683.0
# 1464   FMD  MN095360.1  tblastn      Lpro        None      1104.0    1694.0
# 1476   FMD  MN095361.1  tblastn      Lpro        None      1084.0    1674.0
# 1488   FMD  MN095362.1  tblastn      Lpro        None      1104.0    1694.0
# 1500   FMD  MN095363.1  tblastn      Lpro        None      1084.0    1674.0
# 1756   FMD  MN366244.1  tblastn       VP1        None      3259.0    3885.0
# 1877   FMD  OK318512.1  tblastn        2A        None      3835.0    3885.0
# 1908   FMD  OK318519.1  tblastn      Lpro        None      1078.0    1668.0
# 1925   FMD  OK318524.1  tblastn        2A        None      3833.0    3883.0
# 1949   FMD  OK318528.1  tblastn        2A        None      3836.0    3886.0
# 1961   FMD  OK318541.1  tblastn        2A        None      3818.0    3868.0
# 1972   FMD  OP957418.1  tblastn       VP1        None      3273.0    3905.0
# 1984   FMD  PV805280.1  tblastn       VP1        None      3272.0    3904.0
# 1996   FMD  PV805281.1  tblastn       VP1        None      3271.0    3903.0
# 2014   FMD  PV805282.1  tblastn     3Cpro        None      6063.0    6689.0
# 2008   FMD  PV805282.1  tblastn       VP1        None      3276.0    3908.0
# 2025   FMD  PV805283.1  tblastn        3B        None      5835.0    6044.0
# 2026   FMD  PV805283.1  tblastn     3Cpro        None      6060.0    6686.0
# 2020   FMD  PV805283.1  tblastn       VP1        None      3273.0    3905.0
# 1048   FMD  DQ989316.1  tblastn       VP1        None      3510.0    3977.0
# 1047   FMD  DQ989316.1  tblastn       VP3        None      2694.0    2927.0
# 1205   FMD  FJ175666.1  tblastn        2A        None         NaN       NaN
# 877    FMD  AY687334.1  tblastn       VP4        None      1684.0    1938.0
# 869    FMD  AY687333.1  tblastn        2A        None      3881.0    3934.0
# 881    FMD  AY687334.1  tblastn        2A        None      3877.0    3930.0
# 878    FMD  AY687334.1  tblastn       VP2        None      1939.0    2592.0
#
#      strand        status  coverage  ...  truth_name  truth_start truth_end  \
# 868       +            ok    1.0000  ...         VP1       3251.0    3886.0
# 880       +            ok    1.0000  ...         VP1       3250.0    3882.0
# 1253      +            ok    0.9444  ...          2A       3890.0    3943.0
# 905       +            ok    0.9444  ...          2A       3931.0    3984.0
# 1013      +            ok    0.9444  ...          2A       3977.0    4030.0
# 1056      +            ok    0.9801  ...        Lpro       1182.0    1784.0
# 1068      +            ok    0.9801  ...        Lpro       1178.0    1780.0
# 1241      +            ok    0.9444  ...          2A       3889.0    3942.0
# 1260      +            ok    0.9801  ...        Lpro       1101.0    1703.0
# 1277      +            ok    0.9444  ...          2A       3909.0    3956.0
# 1276      +            ok    1.0000  ...         VP1       3270.0    3908.0
# 1300      +            ok    0.9953  ...         VP1       3352.0    3978.0
# 1308      +            ok    0.9751  ...        Lpro       1051.0    1647.0
# 1312      +            ok    1.0000  ...         VP1       3220.0    3873.0
# 1324      +            ok    1.0000  ...         VP1       3227.0    3865.0
# 1336      +            ok    1.0000  ...         VP1       3221.0    3847.0
# 1348      +            ok    1.0000  ...         VP1       3210.0    3848.0
# 1360      +            ok    1.0000  ...         VP1       3284.0    3925.0
# 1372      +            ok    1.0000  ...         VP1       2795.0    3421.0
# 1612      +            ok    1.0000  ...         VP1       3271.0    3909.0
# 1380      +            ok    0.9801  ...        Lpro       1102.0    1704.0
# 1416      +            ok    0.9801  ...        Lpro       1090.0    1692.0
# 1428      +            ok    0.9801  ...        Lpro       1097.0    1699.0
# 1440      +            ok    0.9801  ...        Lpro       1079.0    1681.0
# 1452      +            ok    0.9801  ...        Lpro       1081.0    1683.0
# 1464      +            ok    0.9801  ...        Lpro       1092.0    1694.0
# 1476      +            ok    0.9801  ...        Lpro       1072.0    1674.0
# 1488      +            ok    0.9801  ...        Lpro       1092.0    1694.0
# 1500      +            ok    0.9801  ...        Lpro       1072.0    1674.0
# 1756      +            ok    1.0000  ...         VP1       3259.0    3891.0
# 1877      +            ok    0.9444  ...          2A       3832.0    3885.0
# 1908      +            ok    0.9801  ...        Lpro       1066.0    1668.0
# 1925      +            ok    0.9444  ...          2A       3830.0    3883.0
# 1949      +            ok    0.9444  ...          2A       3833.0    3886.0
# 1961      +            ok    0.9444  ...          2A       3815.0    3868.0
# 1972      +            ok    1.0000  ...         VP1       3273.0    3911.0
# 1984      +            ok    1.0000  ...         VP1       3272.0    3910.0
# 1996      +            ok    1.0000  ...         VP1       3271.0    3909.0
# 2014      +            ok    0.9812  ...       3Cpro       6051.0    6689.0
# 2008      +            ok    1.0000  ...         VP1       3276.0    3914.0
# 2025      +            ok    0.9859  ...          3B       5835.0    6047.0
# 2026      +            ok    0.9812  ...       3Cpro       6048.0    6686.0
# 2020      +            ok    1.0000  ...         VP1       3273.0    3911.0
# 1048      +            ok    0.7488  ...         NaN          NaN       NaN
# 1047      +  low_coverage    0.3591  ...         NaN          NaN       NaN
# 1205      +        no_hit    0.0000  ...          2A       3986.0    4039.0
# 877       +            ok    1.0000  ...         NaN          NaN       NaN
# 869       +            ok    1.0000  ...          2A       3887.0    3934.0
# 881       +            ok    1.0000  ...          2A       3883.0    3930.0
# 878       +            ok    1.0000  ...         VP2       1639.0    2592.0
#
#       best_overlap_name  best_iou     iou  name_match  coord_correct  \
# 868                 VP1    0.9906  0.9906        True           True
# 880                 VP1    0.9905  0.9905        True           True
# 1253                 2A    0.9444  0.9444        True           True
# 905                  2A    0.9444  0.9444        True           True
# 1013                 2A    0.9444  0.9444        True           True
# 1056               Lpro    0.9801  0.9801        True           True
# 1068               Lpro    0.9801  0.9801        True           True
# 1241                 2A    0.9444  0.9444        True           True
# 1260               Lpro    0.9801  0.9801        True           True
# 1277                 2A    0.9412  0.9412        True           True
# 1276                VP1    0.9906  0.9906        True           True
# 1300                VP1    0.9952  0.9952        True           True
# 1308               Lpro    0.9749  0.9749        True           True
# 1312                VP1    0.9908  0.9908        True           True
# 1324                VP1    0.9906  0.9906        True           True
# 1336                VP1    0.9904  0.9904        True           True
# 1348                VP1    0.9906  0.9906        True           True
# 1360                VP1    0.9907  0.9907        True           True
# 1372                VP1    0.9904  0.9904        True           True
# 1612                VP1    0.9906  0.9906        True           True
# 1380               Lpro    0.9801  0.9801        True           True
# 1416               Lpro    0.9801  0.9801        True           True
# 1428               Lpro    0.9801  0.9801        True           True
# 1440               Lpro    0.9801  0.9801        True           True
# 1452               Lpro    0.9801  0.9801        True           True
# 1464               Lpro    0.9801  0.9801        True           True
# 1476               Lpro    0.9801  0.9801        True           True
# 1488               Lpro    0.9801  0.9801        True           True
# 1500               Lpro    0.9801  0.9801        True           True
# 1756                VP1    0.9905  0.9905        True           True
# 1877                 2A    0.9444  0.9444        True           True
# 1908               Lpro    0.9801  0.9801        True           True
# 1925                 2A    0.9444  0.9444        True           True
# 1949                 2A    0.9444  0.9444        True           True
# 1961                 2A    0.9444  0.9444        True           True
# 1972                VP1    0.9906  0.9906        True           True
# 1984                VP1    0.9906  0.9906        True           True
# 1996                VP1    0.9906  0.9906        True           True
# 2014              3Cpro    0.9812  0.9812        True           True
# 2008                VP1    0.9906  0.9906        True           True
# 2025                 3B    0.9859  0.9859        True           True
# 2026              3Cpro    0.9812  0.9812        True           True
# 2020                VP1    0.9906  0.9906        True           True
# 1048                NaN    0.0000  0.0000       False          False
# 1047                NaN    0.0000  0.0000       False          False
# 1205                NaN    0.0000  0.0000        True          False
# 877                 VP2    0.2673  0.0000       False          False
# 869                  2A    0.8889  0.8889        True          False
# 881                  2A    0.8889  0.8889        True          False
# 878                 VP2    0.6855  0.6855        True          False
#
#       exact_match      failure_mode
# 868         False   Boundary offset
# 880         False   Boundary offset
# 1253        False   Boundary offset
# 905         False   Boundary offset
# 1013        False   Boundary offset
# 1056        False   Boundary offset
# 1068        False   Boundary offset
# 1241        False   Boundary offset
# 1260        False   Boundary offset
# 1277        False   Boundary offset
# 1276        False   Boundary offset
# 1300        False   Boundary offset
# 1308        False   Boundary offset
# 1312        False   Boundary offset
# 1324        False   Boundary offset
# 1336        False   Boundary offset
# 1348        False   Boundary offset
# 1360        False   Boundary offset
# 1372        False   Boundary offset
# 1612        False   Boundary offset
# 1380        False   Boundary offset
# 1416        False   Boundary offset
# 1428        False   Boundary offset
# 1440        False   Boundary offset
# 1452        False   Boundary offset
# 1464        False   Boundary offset
# 1476        False   Boundary offset
# 1488        False   Boundary offset
# 1500        False   Boundary offset
# 1756        False   Boundary offset
# 1877        False   Boundary offset
# 1908        False   Boundary offset
# 1925        False   Boundary offset
# 1949        False   Boundary offset
# 1961        False   Boundary offset
# 1972        False   Boundary offset
# 1984        False   Boundary offset
# 1996        False   Boundary offset
# 2014        False   Boundary offset
# 2008        False   Boundary offset
# 2025        False   Boundary offset
# 2026        False   Boundary offset
# 2020        False   Boundary offset
# 1048        False      Not in truth
# 1047        False      Not in truth
# 1205        False        Not lifted
# 877         False  Possible overlap
# 869         False      Wrong coords
# 881         False      Wrong coords
# 878         False      Wrong coords
#
# [50 rows x 22 columns]
